# %%
import pandas as pd

# %%
dataset_1 = pd.read_csv('dataset_1.csv')
dataset_2 = pd.read_csv('dataset_2.csv')
dataset_3 = pd.read_csv('dataset_3.csv')
dataset_4 = pd.read_csv('dataset_4.csv', low_memory=False)

# %%
# get data above 2020
dataset_1 = dataset_1[dataset_1['Year'] >= 2020]
print(dataset_1.shape)

dataset_3 = dataset_3[dataset_3['Year'] >= 2020]
print(dataset_3.shape)

dataset_4 = dataset_4[dataset_4['Year'] >= 2020]
print(dataset_4.shape)
# Out:
# (31428, 14)
# (206940, 15)
# (115810, 11)

# %%
# change the state names to lowercase
dataset_1['State'] = dataset_1['State'].str.lower()
dataset_2['State'] = dataset_2['State'].str.lower()
# Out:
# <ipython-input-89-852952893cc1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_1['State'] = dataset_1['State'].str.lower()

# %%
# change Jurisdiction to State and convert to lowercase
dataset_3 = dataset_3.rename(columns={'Jurisdiction': 'State'})
dataset_3['State'] = dataset_3['State'].str.lower()

# %%
# rename Jurisdiction to State and convert to lowercase
dataset_4.rename(columns={'Jurisdiction': 'State'}, inplace=True)
dataset_4['State'] = dataset_4['State'].str.lower()

# %%
# merge datasets 1 and 2, group by state and year
dataset_12 = pd.merge(dataset_1, dataset_2, how='inner', on=['State', 'Year'])
dataset_12.shape
# Out:
# (246510, 18)

# %%
# group by state and year
dataset_3 = dataset_3.groupby(['State', 'Year']).sum().reset_index()
dataset_3.head()
# Out:
# <ipython-input-93-80b5f7e9f1ef>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset_3 = dataset_3.groupby(['State', 'Year']).sum().reset_index()
#      State  Year   Week  Number of Deaths  Suppress  \
# 0  alabama  2020  37140             89436       0.0
# 1  alabama  2021  35792             88004       0.0
# 2  alabama  2022  35446             87846       0.0
# 3  alabama  2023  17112             58653       0.0
# 4   alaska  2020   4318              2626       0.0
#
#    Average Number of Deaths in Time Period  Difference from 2015-2019 to 2020  \
# 0                                    89436                             3299.0
# 1                                    88004                             3491.0
# 2                                    87846                             3493.0
# 3                                    58653                             1495.0
# 4                                     2626                               79.0
#
#    Percent Difference from 2015-2019 to 2020
# 0                                     7913.5
# 1                                     9865.5
# 2                                    11872.6
# 3                                     6301.5
# 4                                      513.0

# %%
# group dataset 12 by state and year
dataset_12 = dataset_12.groupby(['State', 'Year']).sum().reset_index()
dataset_12.head()
# Out:
# <ipython-input-94-206875bda403>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset_12 = dataset_12.groupby(['State', 'Year']).sum().reset_index()
#      State  Year  Observed Number  Upper Bound Threshold  Exceeds Threshold  \
# 0  alabama  2022        4375272.0                4270824               2088
# 1  alabama  2023         718878.0                 755472                126
# 2   alaska  2022         399048.0                 422712               1008
# 3   alaska  2023          62106.0                  77298                 78
# 4  arizona  2022        5372616.0                5224392               1848
#
#    Average Expected Count  Excess Estimate  Total Excess Estimate  \
# 0                 4040640           355320               86401872
# 1                  715050            18780               15079572
# 2                  359352            42792                9047736
# 3                   65976             3126                1579086
# 4                 4901040           495672              121095672
#
#    Percent Excess Estimate  Data Value
# 0             32896.055757    19128972
# 1              1717.115517     3277941
# 2             45436.435617     2399469
# 3              3170.938034      395160
# 4             37980.293773    24267534

# %%
# merge datasets 12 and 3, group by state and year
dataset_123 = pd.merge(dataset_12, dataset_3, how='inner', on=['State', 'Year'])
dataset_123.head()
# Out:
#      State  Year  Observed Number  Upper Bound Threshold  Exceeds Threshold  \
# 0  alabama  2022        4375272.0                4270824               2088
# 1  alabama  2023         718878.0                 755472                126
# 2   alaska  2022         399048.0                 422712               1008
# 3   alaska  2023          62106.0                  77298                 78
# 4  arizona  2022        5372616.0                5224392               1848
#
#    Average Expected Count  Excess Estimate  Total Excess Estimate  \
# 0                 4040640           355320               86401872
# 1                  715050            18780               15079572
# 2                  359352            42792                9047736
# 3                   65976             3126                1579086
# 4                 4901040           495672              121095672
#
#    Percent Excess Estimate  Data Value   Week  Number of Deaths  Suppress  \
# 0             32896.055757    19128972  35446             87846       0.0
# 1              1717.115517     3277941  17112             58653       0.0
# 2             45436.435617     2399469   4432              2820       0.0
# 3              3170.938034      395160   1682              1607       0.0
# 4             37980.293773    24267534  33490             98594       0.0
#
#    Average Number of Deaths in Time Period  Difference from 2015-2019 to 2020  \
# 0                                    87846                             3493.0
# 1                                    58653                             1495.0
# 2                                     2820                              125.0
# 3                                     1607                               48.0
# 4                                    98594                             6579.0
#
#    Percent Difference from 2015-2019 to 2020
# 0                                    11872.6
# 1                                     6301.5
# 2                                      766.2
# 3                                      300.7
# 4                                    12629.9

# %%
# group dataset_4 by state and year
dataset_4 = dataset_4.groupby(['State', 'Year']).sum().reset_index()
dataset_4.head()
# Out:
# <ipython-input-96-696c88a2eb97>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset_4 = dataset_4.groupby(['State', 'Year']).sum().reset_index()
#      State  Year   Week  Number of Deaths
# 0  alabama  2020  17172          128708.0
# 1  alabama  2021  16536          133922.0
# 2  alabama  2022  16536          121896.0
# 3  alabama  2023   8290           80130.0
# 4   alaska  2020  12846            9162.0

# %%
# merge datasets 123 and 4, group by state and year
dataset_1234 = pd.merge(dataset_123, dataset_4, how='inner', on=['State', 'Year'])
dataset_1234.head()
# Out:
#      State  Year  Observed Number  Upper Bound Threshold  Exceeds Threshold  \
# 0  alabama  2022        4375272.0                4270824               2088
# 1  alabama  2023         718878.0                 755472                126
# 2   alaska  2022         399048.0                 422712               1008
# 3   alaska  2023          62106.0                  77298                 78
# 4  arizona  2022        5372616.0                5224392               1848
#
#    Average Expected Count  Excess Estimate  Total Excess Estimate  \
# 0                 4040640           355320               86401872
# 1                  715050            18780               15079572
# 2                  359352            42792                9047736
# 3                   65976             3126                1579086
# 4                 4901040           495672              121095672
#
#    Percent Excess Estimate  Data Value  Week_x  Number of Deaths_x  Suppress  \
# 0             32896.055757    19128972   35446               87846       0.0
# 1              1717.115517     3277941   17112               58653       0.0
# 2             45436.435617     2399469    4432                2820       0.0
# 3              3170.938034      395160    1682                1607       0.0
# 4             37980.293773    24267534   33490               98594       0.0
#
#    Average Number of Deaths in Time Period  Difference from 2015-2019 to 2020  \
# 0                                    87846                             3493.0
# 1                                    58653                             1495.0
# 2                                     2820                              125.0
# 3                                     1607                               48.0
# 4                                    98594                             6579.0
#
#    Percent Difference from 2015-2019 to 2020  Week_y  Number of Deaths_y
# 0                                    11872.6   16536            121896.0
# 1                                     6301.5    8290             80130.0
# 2                                      766.2   12854             10372.0
# 3                                      300.7    5668              6381.0
# 4                                    12629.9   16536            149620.0

# %%
dataset_1234.shape
# Out:
# (106, 18)

# %%
dataset_1234['State'].unique()
# Out:
# array(['alabama', 'alaska', 'arizona', 'arkansas', 'california',
#        'colorado', 'connecticut', 'delaware', 'district of columbia',
#        'florida', 'georgia', 'hawaii', 'idaho', 'illinois', 'indiana',
#        'iowa', 'kansas', 'kentucky', 'louisiana', 'maine', 'maryland',
#        'massachusetts', 'michigan', 'minnesota', 'mississippi',
#        'missouri', 'montana', 'nebraska', 'nevada', 'new hampshire',
#        'new jersey', 'new mexico', 'new york', 'north carolina',
#        'north dakota', 'ohio', 'oklahoma', 'oregon', 'pennsylvania',
#        'puerto rico', 'rhode island', 'south carolina', 'south dakota',
#        'tennessee', 'texas', 'united states', 'utah', 'vermont',
#        'virginia', 'washington', 'west virginia', 'wisconsin', 'wyoming'],
#       dtype=object)
